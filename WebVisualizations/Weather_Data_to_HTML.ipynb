# %%
import pandas as pd

# %%
weather_df = pd.read_csv('.//Resources/clean_cities_weather_data.csv')
weather_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    ushuaia          40      AR  1569303867        81 -54.81  -68.31
# 1      kapaa          90      US  1569303701        83  22.08 -159.32
# 2  kavaratti          75      IN  1569303892        79  10.57   72.64
# 3    rikitea          74      PF  1569303892        72 -23.12 -134.97
# 4     weinan           0      CN  1569303893        60  34.50  109.46
#
#    Max Temp  Wind Speed
# 0     44.60        5.82
# 1     80.60        6.93
# 2     84.20        4.70
# 3     69.89       12.80
# 4     78.01        2.24

# %%
weather_df_HTML = weather_df.to_html()
print(weather_df_HTML)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ushuaia</td>
#       <td>40</td>
#       <td>AR</td>
#       <td>1569303867</td>
#       <td>81</td>
#       <td>-54.81</td>
#       <td>-68.31</td>
#       <td>44.60</td>
#       <td>5.82</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>kapaa</td>
#       <td>90</td>
#       <td>US</td>
#       <td>1569303701</td>
#       <td>83</td>
#       <td>22.08</td>
#       <td>-159.32</td>
#       <td>80.60</td>
#       <td>6.93</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>kavaratti</td>
#       <td>75</td>
#       <td>IN</td>
#       <td>1569303892</td>
# ...
